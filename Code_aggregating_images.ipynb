# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai

# %%
import tensorflow as tf

# %%
import os

# %%
ll= os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/bad_resized_new')

# %%
len(ll)
# Out:
# 910

# %% [markdown]
# **To aggregate images, let's have a look at that example and use the code below to something like this.**

# %%
# !ls
# Out:
# drive  sample_data

# %%
import os
images = os.listdir()

# %%
images
# Out:
# ['.config', 'drive', 'sample_data']

# %%
img= 'B1_1_1.jpeg'

# %%
from PIL import Image

# %%
Image.open(images[0])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=256x256 at 0x7F9B411A1AD0>

# %%
Image.open(images[1])
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=256x256 at 0x7F9B411CF590>

# %%
img_11 = tf.keras.utils.img_to_array(
    Image.open(images[0]), data_format=None, dtype=None
)

# %%
img_22 = tf.keras.utils.img_to_array(
    Image.open(images[1]), data_format=None, dtype=None
)

# %%
img_x = img_11 + img_22

# %%
ii = [img_11 , img_22]

# %%
tf.keras.utils.array_to_img(sum(ii))
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F9B41143F10>

# %%
img_x.shapedef Adding_masks( list_images):
  masks_to_imgs =[]
  for img_ in list_images:
    masks_to_imgs.append(tf.keras.utils.img_to_array(Image.open(img_), data_format=None, dtype=None))
  
  return tf.keras.utils.array_to_img(sum(masks_to_imgs))
# Out:
# (256, 256, 1)

# %%
img_xx = tf.keras.utils.array_to_img(img_x)

# %%
img_xx
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F9B41155210>

# %%
def Adding_masks( list_images):
  masks_to_imgs =[]
  for img_ in list_images:
    masks_to_imgs.append(tf.keras.utils.img_to_array(Image.open(img_), data_format=None, dtype=None))
  
  return tf.keras.utils.array_to_img(sum(masks_to_imgs))

# %%
mask_1  = Adding_masks(images)
mask_1.save('B1_1.jpeg')

# %%
mask_1
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F9B410C7910>

# %%
##HHHHH

# %%
# %cd "/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai/"
# Out:
# /content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai

# %%
import tensorflow as tf

# %%
# !ls
# Out:
# B1_4  B1_5  masks-20220517T201335Z-001

# %% [markdown]
# #**Concatenation's code**

# %%
import os

# %%
os.listdir('B1_4')
# Out:
# ['masks', 'images']

# %%
#essai = os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai')
#essa = ('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai')

# %%
#essa = ('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai')

# %%
essai = os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/bad_resized_new')

# %%
essai[609]
# Out:
# 'H213_2'

# %%
essa = ('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/bad_resized_new')

# %%
dc=os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/concatenated_img_bad_resized')

# %%
len(dc)
# Out:
# 909

# %%
essai[]

# %%
#for i in essai:
imag = os.listdir(essa + '/' + essai[0] + '/' + 'masks/')

# %%
for j in range(1,9):
  Image.open(essa + '/' + essai[0] + '/' + 'masks' + '/' + imag[j])

# %% [markdown]
# **The code for aggregating**

# %%
def Adding_masks( list_images):
  masks_to_imgs =[]
  for img_ in list_images:
    masks_to_imgs.append(tf.keras.utils.img_to_array(Image.open(essa + '/' + i + '/' + 'masks/' + img_), data_format=None, dtype=None))
  
  return tf.keras.utils.array_to_img(sum(masks_to_imgs))

# %%
Ii = []
mas = []
for i in essai[610:]:
  Ima = os.listdir(essa + '/' + i + '/' + 'masks')
  mas_1 = Adding_masks(Ima)
  os.chdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/concatenated_img_bad_resized')
  mas_1.save(i +'.png')
  Ii.append(mas_1)

# %%
len(os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/concatenated_img_bad_resized'))
# Out:
# 609

# %%
cont= os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/concatenated_img_bad_resized')

# %%
cont[609]
# Out:
# 'H213_3.png'

# %%
imga= os.listdir('/content/drive/MyDrive/PlumUnzinveau/Prune/resized_nveau/bad_resized_new')

# %%
len(imga)
# Out:
# 910

# %%
imga[610]
# Out:
# 'E16_3.jpg'

# %% [markdown]
# **I deleted the folder H213_2**

# %% [markdown]
# #**Images extraction**

# %%
import glob 
import shutil

# %%
essai = os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai')
essa = ('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai')

# %%
#Extract images from many folders situated in the folder'extracted'  
destination_path = "/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai/"
pattern = "/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/essai/b/*/*"  
for img in glob.glob(pattern):
    shutil.copy(img, destination_path)

# %%
destination_path= "/"

# %%
essai = os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/bad_resized_new')
essa = ('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/bad_resized_new')

# %%
def list_img(list_images):   
  imgs =[]
  for img_ in list_images:
    imgs.append(Image.open(essa + '/' + i + '/' + 'images/' + img_))
  
  return(imgs)

# %%
#Ii = []
#mas = []

for i in essai:
  Ima = os.listdir(essa + '/' + i + '/' + 'images')
  ma_1 = list_img(Ima)
  for img in ma_1:
    os.chdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/data_Unet_model/original_image/')
    img.save(Ima[0])
  #shutil.copy(img, destination_path)

  
  #shutil.copy(ma_1, destination_path)


  #Ii.append(mas_1)

# %%
ori= os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/data_Unet_model/original_image')

# %%
len(ori)
# Out:
# 909

# %%
cont= os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/data_Unet_model/concatenated_img_bad_resized')

# %%
len(cont)
# Out:
# 909

# %%
ori[0]
# Out:
# 'H223_1.jpg'

# %%
cont[0]
# Out:
# 'I56_3.png'

# %%
import pandas as pd

# %%
jil= os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/Unet_preprocessing/data_Unet_model/concatenated_img_bad_resized')

# %%
jill= os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/Unet_preprocessing/data_Unet_model/original_image')

# %%
len(jil)
# Out:
# 909

# %%
for i in range(len(jil)):
  print (sorted(jil)[i],sorted(jill)[i])

# %% [markdown]
# #**Masks with extension .png**

# %%
essai = os.listdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/bad_resized_new')
essa = ('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/bad_resized_new')

# %%
def Adding_masks( list_images):
  masks_to_imgs =[]
  for img_ in list_images:
    masks_to_imgs.append(tf.keras.utils.img_to_array(Image.open(essa + '/' + i + '/' + 'masks/' + img_), data_format=None, dtype=None))
  
  return tf.keras.utils.array_to_img(sum(masks_to_imgs))

# %%
Ii = []
mas = []
for i in essai:
  Ima = os.listdir(essa + '/' + i + '/' + 'masks')
  mas_1 = Adding_masks(Ima)
  os.chdir('/content/drive/MyDrive/Colab Notebooks/Aims essay topic_Carele/interesting_code_preprocessing/test_irene/concatenated_img_bad_resized')
  mas_1.save(i +'.png')
  Ii.append(mas_1)
